# %%
import sys 

sys.path.append('./project_playground/QEC-with-spin-qubits/')
from RotatedSurfaceCode import RotatedSurfaceCode
from SurfaceCode3CX import SurfaceCode3CX
from XZZXCode import XZZXCode
from HeavyHEXFloquetColorCode import HeavyHexFloquetColorCode
from HeavyHEXHoneycombFloquetCode import HeavyHexHoneycombFloquetCode
from XYZ2Code import XYZ2Code
import plot_utils

import matplotlib.pyplot as plt
import numpy as np
import json
from scipy.optimize import fsolve
from math import comb

# %%
code = RotatedSurfaceCode(d=3, T = 3,logical_observable='X', gate_error_1q=0.001)
# code.draw_lattice()
code.draw_lattice(boundaries = True, connectivity = True, schedule = False, logicals=True)

# %%
SurfaceCode3CX(d=9, T = 9,logical_observable='X', gate_error_1q=0.001).stim_circuit.num_qubits
# Out:
# 241

# %%
d = 3

2*d**2 + (d-1)**2 + (2*d-2)
# Out:
# 26

# %%
# v_a = 2 
# v_q = 1

# v_a = 2
# v_q = 2

v_a = 4.5 
v_q = 1.5

d= 3
(v_a + v_q)*(d**2)
# Out:
# 54.0

# %%
XYZ2Code(d=3, T = 0,logical_observable='Y', gate_error_1q=0.001).stim_circuit.num_qubits
# Out:
# 36

# %%
HeavyHexHoneycombFloquetCode(d=3, T = 0,logical_observable='Z', gate_error_1q=0.001).stim_circuit.num_qubits
# Out:
# 432

# %%
code = SurfaceCode3CX(d=3, T = 3,logical_observable='X', gate_error_1q=0.001)
# code.draw_lattice()
code.draw_lattice(boundaries = True, connectivity = True, schedule = False, logicals=True)

# %%
code = XZZXCode(d=3, T = 3,logical_observable='X', gate_error_1q=0.001)
# code.draw_lattice()
code.draw_lattice(boundaries = True, connectivity = True, schedule = False,)

# %%
code = XYZ2Code(d=3, T = 3,logical_observable='Y', gate_error_1q=0.001)
# code.draw_lattice()
code.draw_lattice(boundaries = True, connectivity = True, schedule = False,)

# %%
code = HeavyHexFloquetColorCode(d=3, T = 3,logical_observable='Y', gate_error_1q=0.001)
# code.draw_lattice()
code.draw_lattice()

# %%
code = HeavyHexHoneycombFloquetCode(d=3, T = 3,logical_observable='Y', gate_error_1q=0.001)
# code.draw_lattice()
code.draw_lattice()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[14], line 3
#       1 code = HeavyHexHoneycombFloquetCode(d=3, T = 3,logical_observable='Y', gate_error_1q=0.001)
#       2 # code.draw_lattice()
# ----> 3 code.draw_lattice()
#
# AttributeError: 'HeavyHexHoneycombFloquetCode' object has no attribute 'draw_lattice'
